# %%
# %sql
ALTER TABLE databrick_by_databrick.default.invoices
ADD COLUMN invoice_date_new DATE;

SELECT * FROM databrick_by_databrick.default.invoices;

# %%
# %sql
UPDATE databrick_by_databrick.default.invoices
SET invoice_date_new = try_to_date(invoice_date, 'M/d/yyyy');

# %%
# %sql
select * from databrick_by_databrick.default.invoices;

# %%
# %sql
ALTER TABLE databrick_by_databrick.default.invoices
SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name'
);

ALTER TABLE databrick_by_databrick.default.invoices
DROP COLUMN invoice_date;

ALTER TABLE databrick_by_databrick.default.invoices
RENAME COLUMN invoice_date_new TO invoice_date;
